# %% [markdown]
# <a href="https://colab.research.google.com/github/FLC-ML/practicespace/blob/kakukula-patch-1/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Import Libraries

# %%
# import packages
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import numpy as np
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Load Data

# %%
# load data (specific to google drive)
X_test = np.load('/content/drive/My Drive/ML Group/Datasets/data/X_test.npy')
y_test = np.load('/content/drive/My Drive/ML Group/Datasets/data/y_test.npy')

X = np.load('/content/drive/My Drive/ML Group/Datasets/data/X_reference.npy')
y = np.load('/content/drive/My Drive/ML Group/Datasets/data/y_reference.npy')

X_fine = np.load('/content/drive/My Drive/ML Group/Datasets/data/X_finetune.npy')
y_fine = np.load('/content/drive/My Drive/ML Group/Datasets/data/y_finetune.npy')

print("X Reference Dataset Shape: ", X.shape)
print("y Reference Dataset Shape: ", y.shape)
print("X Test Dataset Shape: ", X_test.shape)
print("y Test Dataset Shape: ", y_test.shape)
print("X Finetuning Dataset Shape: ", X_fine.shape)
print("y Finetuning Dataset Shape: ", y_fine.shape)
# Out:
# X Reference Dataset Shape:  (60000, 1000)
# y Reference Dataset Shape:  (60000,)
# X Test Dataset Shape:  (3000, 1000)
# y Test Dataset Shape:  (3000,)
# X Finetuning Dataset Shape:  (3000, 1000)
# y Finetuning Dataset Shape:  (3000,)

# %% [markdown]
# Plot

# %%
C_glabrata = np.where(y==29)
C_albicans = np.where(y==28)
P_aeruginosa_2 = np.where(y==27)
P_aeruginosa_1 = np.where(y==26)
S_enterica = np.where(y==25)
S_marcescens = np.where(y==24)
P_mirabilis = np.where(y==23)
E_cloacae = np.where(y==22)
K_aerongenes = np.where(y==21)
K_pneumoniae_2 = np.where(y==20)
K_pneumoniae_1 = np.where(y==19)
E_coli_2 = np.where(y==18)
E_coli_1 = np.where(y==17)
E_faecium = np.where(y==16)
E_faecalis_2 = np.where(y==15)
E_faecalis_1 = np.where(y==14)
S_sanguinis = np.where(y==13)
Group_G_Strep = np.where(y==12)
Group_C_Strep = np.where(y==11)
Group_B_Strep = np.where(y==10)
Group_A_Strep = np.where(y==9)
S_pneumoniae_2 = np.where(y==8)
S_pneumoniae_1 = np.where(y==7)
S_lugdunensis = np.where(y==6)
S_epidermindis = np.where(y==5)
MSSA_3 = np.where(y==4)
MSSA_2 = np.where(y==3)
MSSA_1 = np.where(y==2)
MRSA_2 = np.where(y==1)
MRSA_1_iso = np.where(y==0)

# Plots of signals

plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[0], color = 'black', linewidth = 0.5, label = 'C. albicans')
plt.legend()
plt.savefig("C. albicans.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[2000], color = 'black', linewidth = 0.5, label = 'C glabrata')
plt.legend()
plt.savefig("C. glabrata.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[4000], color = 'black', linewidth = 0.5, label = 'K. aerogenes')
plt.legend()
plt.savefig("K. aerogenes.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[6000], color = 'black', linewidth = 0.5, label = 'E. coli 1')
plt.legend()
plt.savefig("E. coli 1.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[8000], color = 'black', linewidth = 0.5, label = 'E. coli 2')
plt.legend()
plt.savefig("E. coli 2.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[10000], color = 'black', linewidth = 0.5, label = '"E. faecium')
plt.legend()
plt.savefig("E. faecium.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[12000], color = 'black', linewidth = 0.5, label = 'E. faecalis 1')
plt.legend()
plt.savefig("E. faecalis 1.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[14000], color = 'black', linewidth = 0.5, label = 'E. faecalis 2')
plt.legend()
plt.savefig("E. faecalis 2.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[16000], color = 'black', linewidth = 0.5, label = 'E. faecalis 2')
plt.legend()
plt.savefig("E. cloacae 2.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[18000], color = 'black', linewidth = 0.5, label = '')
plt.legend()
plt.savefig("K. pneumoniae 1.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[20000], color = 'black', linewidth = 0.5, label = 'K. pneumoniae 2')
plt.legend()
plt.savefig("K. pneumoniae 2.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[22000], color = 'black', linewidth = 0.5, label = 'P. mirabilis')
plt.legend()
plt.savefig("P. mirabilis.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[24000], color = 'black', linewidth = 0.5, label = 'P. aeruginosa 1')
plt.legend()
plt.savefig("P. aeruginosa 1.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[26000], color = 'black', linewidth = 0.5, label = 'P. aeruginosa 2')
plt.legend()
plt.savefig("P. aeruginosa 2.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[28000], color = 'black', linewidth = 0.5, label = 'MSSA 1')
plt.legend()
plt.savefig("MSSA 1.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[30000], color = 'black', linewidth = 0.5, label = 'MSSA 3')
plt.legend()
plt.savefig("MSSA 3.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[32000], color = 'black', linewidth = 0.5, label = 'MRSA 1')
plt.legend()
plt.savefig("MRSA 1.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[34000], color = 'black', linewidth = 0.5, label = 'MRSA 2')
plt.legend()
plt.savefig("MRSA 2.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[36000], color = 'black', linewidth = 0.5, label = 'MSSA 2')
plt.legend()
plt.savefig("MSSA 2.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[38000], color = 'black', linewidth = 0.5, label = 'S. enterica')
plt.legend()
plt.savefig("S. enterica.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[40000], color = 'black', linewidth = 0.5, label = 'S. epidermidis')
plt.legend()
plt.savefig("S. epidermidis.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[42000], color = 'black', linewidth = 0.5, label = 'S. lugdunensis')
plt.legend()
plt.savefig("S. lugdunensis.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[44000], color = 'black', linewidth = 0.5, label = 'S. marcescens')
plt.legend()
plt.savefig("S. marcescens.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[46000], color = 'black', linewidth = 0.5, label = 'S. pneumoniae 2')
plt.legend()
plt.savefig("S. pneumoniae 2.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[48000], color = 'black', linewidth = 0.5, label = 'S. pneumoniae 1')
plt.legend()
plt.savefig("S. pneumoniae 1.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[50000], color = 'black', linewidth = 0.5, label = 'S. sanguinis')
plt.legend()
plt.savefig("S. sanguinis.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[52000], color = 'black', linewidth = 0.5, label = 'Group A Strep.')
plt.legend()
plt.savefig("Group A Strep.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[54000], color = 'black', linewidth = 0.5, label = 'Group B Strep.')
plt.legend()
plt.savefig("Group B Strep.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[56000], color = 'black', linewidth = 0.5, label = 'Group C Strep.')
plt.legend()
plt.savefig("Group C Strep.png")
 
plt.figure()
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[58000], color = 'black', linewidth = 0.5, label = 'Group G Strep.')
plt.legend()
plt.savefig("Group G Strep.png")
# Out:
# No handles with labels found to put in legend.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:174: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:181: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:188: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:195: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:202: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:209: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:216: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:223: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:230: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:237: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
